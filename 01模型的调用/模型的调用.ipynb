# %%
from itertools import chain

from langchain.chat_models import init_chat_model
from langchain_classic.chains.summarize.refine_prompts import prompt_template
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from nbformat.v4 import output_from_msg

from helloworld import response

llm = ChatOpenAI(
    model="google/gemma-3n-e4b",
    openai_api_key="lm-studio",
    openai_api_base="http://localhost:1234/v1"
)

for chunk in llm.stream("介绍一下中国"):
    print(chunk.text, end="|", flush=True)
# Out:
# 好的|，|下面|我|来|为您|介绍|一下|中国|：|
#
# |**|一|、|基本|概|况|**|
#
# |*|   |**|国|名|：|**| 中|华|人民共和国| (|People|'|s| Republic| of| China|)|
# |*|   |**|首都|：|**| 北京| (|Beijing|)|
# |*|   |**|人口|：|**| |约|1|4|.|1|2|亿|（|世界|第一|）|
# |*|   |**|面积|：|**| |9|6|0|万|平方|公里| (|世界|第三|大|)|
# |*|   |**|官方|语言|：|**| |汉语|（|普通|话|）|
# |*|   |**|货币|：|**| 人|民|币| (|CN|Y|,| RMB|)|
# |*|   |**|政治|体制|：|**| |共产党|领导|下的|社会主义|国家|
# |*|   |**|地理|位置|：|**| |位于|东|亚|，|横|跨|亚洲|大陆|东|部|。|
#
# |**|二|、|历史|文化|**|
#
# |*|   |**|悠|久|的历史|：|**| 中国|拥有|数|千|年的|文明|史|，|是|世界上|最|古|老的|文明|之一|。|
# |*|   |**|灿|烂|的|文化|：|**| |孕|育|了|辉|煌|的|文化|，|包括|：|
# |    |*|   |**|哲学|思想|：|**| |儒|家|、|道|家|、|法|家|等|，|对|中国|乃至|世界|产生了|深|远|影响|。|
# |    |*|   |**|文学|艺术|：|**| |诗|歌|、|小说|、|戏|曲|、|绘画|等|，|涌|现|出|众多|经典|作品|。|
# |    |*|   |**|传统|节日|：|**| 春|节|、|元|宵|节|、|清|明|节|、|端|午|节|、|中|秋|节|等|，|承|载|着|丰富的|文化|内|涵|。|
# |    |*|   |**|传统|手|工艺|：|**| |陶瓷|、|丝|绸|、|刺|绣|、|青|铜|器|等|，|体现|了|中国|人民|的|智慧|和|创造|力|。|
# |*|   |**|历史|事件|：|**| |历史上|经历了|秦|朝|、|汉|朝|、|唐|朝|、|宋|朝|、|明|朝|、|清|朝|等|多个|王朝|的|兴|衰|更|迭|，|留|下了|丰富的|历史|遗|迹|和|文化|遗产|。|
#
# |**|三|、|经济|发展|**|
#
# |*|   |**|世界|第二|大|经济|体|：|**| 中国|是|世界|第二|大|经济|体|，|拥有|巨大的|市场|和|强大的|生产|力|。|
# |*|   |**|改革|开放|：|**| |1|9|7|8|年|开始|的|改革|开放|政策|，|是中国|经济|快速|发展|的重要|推动|力|。|
# |*|   |**|产业|结构|：|**| |制造业|、|服务|业|和|农业|是|主要的|经济|支|柱|。|
# |*|   |**|科技|创新|：|**| 在|航|天|、|人工智能|、|高铁|等|领域|取得了|显著|成就|。|
# |*|   |**|对外|贸易|：|**| 是|世界|最大的|进|出口|国|，|积极|参与|全球|经济|合作|。|
#
# |**|四|、|地理|环境|**|
#
# |*|   |**|地形|多样|：|**| |拥有|山|地|、|平|原|、|高原|、|沙漠|等|多种|地形|。|
# |*|   |**|气候|差异|：|**| |气候|类型|多样|，|从|热|带|到|寒|带|都有|。|
# |*|   |**|自然|资源|：|**| |拥有|丰富的|矿|产|资源|、|森林|资源|和|水|资源|。|
# |*|   |**|著名|景观|：|**| 长|江|、|黄|山|、|桂|林|山|水|、|长|城|等|。|
#
# |**|五|、|社会|风|貌|**|
#
# |*|   |**|人口|结构|：|**| 人|口|老|龄|化|问题|日益|突出|。|
# |*|   |**|城市|化|进程|：|**| |城市|化|率|不断|提高|，|城市|规模|持续|扩大|。|
# |*|   |**|社会|发展|：|**| 在|教育|、|医疗|、|环保|等方面|取得了|显著|进展|，|但也|面临|着|一些|挑战|。|
# |*|   |**|文化|多元|：|**| |拥有|多|样的|民族|文化|，|各|民族|和谐|共|处|。|
#
# |**|六|、|旅游|景点|**|
#
# |*|   |**|北京|：|**| |故|宫|、|长|城|、|天|坛|、|颐|和|园|等|。|
# |*|   |**|上海|：|**| 外|滩|、|东方|明|珠|、|南京|路|步行|街|等|。|
# |*|   |**|西安|：|**| |兵|马|俑|、|古|城|墙|、|大|雁|塔|等|。|
# |*|   |**|桂|林|：|**| |漓|江|山|水|、|象|鼻|山|等|。|
# |*|   |**|成都|：|**| |宽|窄|巷|子|、|武|侯|祠|、|都|江|堰|等|。|
# |*|   |**|新疆|：|**| |喀|纳|斯|湖|、|吐|鲁|番|、|天然|大|漠|等|。|
#
# |**|总结|:**|
#
# |中国|是一个|充满|活力|和|魅|力的|国家|，|拥有|悠|久|的历史|、|灿|烂|的|文化|、|快速|发展的|经济|和|多元|的|社会|。| |无论|您|是对|历史|感兴趣|，|还是|对|现代|文化|感兴趣|，|中国|都能|为您|带来|独特的|体验|。|
#
# |**|如果您|想|了解|更多|关于|中国的|具体|方面|，|请|告诉我|您|感兴趣|的|领域|，|例如|：|**|
#
# |*|   |中国|历史|
# |*|   |中国|文化|
# |*|   |中国|经济|
# |*|   |中国|旅游|
# |*|   |中国|科技|
# |*|   |等等|...|
#
# |我会|尽|力|为您|提供|更|详细|的信息|。|||

# %% [markdown]
# 使用Init来初始化

# %%
from langchain.chat_models import init_chat_model
import os

# 设置环境变量（可选，init_chat_model 会用到）
os.environ["OPENAI_API_KEY"] = "lm-studio"

# 使用 init_chat_model
llm = init_chat_model(
    "openai:google/gemma-3n-e4b",  # 模型 ID
    api_key="lm-studio",
    base_url="http://localhost:1234/v1"
)
response= llm.invoke("100字介绍一下阿里巴巴")
print(response.content)
# Out:
# 阿里巴巴集团是一家全球领先的科技公司，业务涵盖电商、零售、云计算、数字支付等多个领域。它以淘宝、天猫等平台为核心，连接全球买家和卖家，赋能中小企业发展。阿里巴巴致力于打造开放的商业生态系统，推动数字经济发展，并积极布局全球创新领域。其影响力遍及全球，是全球最具价值的科技公司之一。
